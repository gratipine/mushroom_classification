# %%
import pandas as pd

# %%
data_in = pd.read_csv("data/mushrooms.csv")

# %%
data_in.head()
# Out:
#   CapShape CapSurface CapColor  Bruises     Odor GillAttachment GillSpacing  \
# 0   convex     smooth    brown     True  pungent           free       close
# 1   convex     smooth   yellow     True   almond           free       close
# 2     bell     smooth    white     True    anise           free       close
# 3   convex      scaly    white     True  pungent           free       close
# 4   convex     smooth     gray    False     none           free     crowded
#
#   GillSize GillColor StalkShape  ... StalkColorAboveRing StalkColorBelowRing  \
# 0   narrow     black  enlarging  ...               white               white
# 1    broad     black  enlarging  ...               white               white
# 2    broad     brown  enlarging  ...               white               white
# 3   narrow     brown  enlarging  ...               white               white
# 4    broad     black   tapering  ...               white               white
#
#   VeilType VeilColor RingNumber    RingType SporePrintColor  Population  \
# 0  partial     white          1     pendant           black   scattered
# 1  partial     white          1     pendant           brown    numerous
# 2  partial     white          1     pendant           brown    numerous
# 3  partial     white          1     pendant           black   scattered
# 4  partial     white          1  evanescent           brown    abundant
#
#    Habitat      Class
# 0    urban  poisonous
# 1  grasses     edible
# 2  meadows     edible
# 3    urban  poisonous
# 4  grasses     edible
#
# [5 rows x 23 columns]

# %%
# probably have to do a specific type of sampling to make sure we don't end up accidentally overrepresenting one group. 
# Not sure about the rest of the stuff. 

# This notebook will be mostly used as an example for how to do some Tensorflow models - I don't care about the classification itself
data_in.groupby("Class").count()
# Out:
#            CapShape  CapSurface  CapColor  Bruises  Odor  GillAttachment  \
# Class
# edible         4208        4208      4208     4208  4208            4208
# poisonous      3916        3916      3916     3916  3916            3916
#
#            GillSpacing  GillSize  GillColor  StalkShape  ...  \
# Class                                                    ...
# edible            4208      4208       4208        4208  ...
# poisonous         3916      3916       3916        3916  ...
#
#            StalkSurfaceBelowRing  StalkColorAboveRing  StalkColorBelowRing  \
# Class
# edible                      4208                 4208                 4208
# poisonous                   3916                 3916                 3916
#
#            VeilType  VeilColor  RingNumber  RingType  SporePrintColor  \
# Class
# edible         4208       4208        4208      4208             4208
# poisonous      3916       3916        3916      3916             3916
#
#            Population  Habitat
# Class
# edible           4208     4208
# poisonous        3916     3916
#
# [2 rows x 22 columns]
